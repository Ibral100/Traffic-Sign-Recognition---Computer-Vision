# %%
import pandas as pd
import cv2
import numpy as np
import os

# recuperer les rois de toutes les images 



path_test_csv = "archive/Test.csv"

df_test = pd.read_csv(path_test_csv)

print(df_test.head())
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path
# 0     53      54       6       5      48      49       16  Test/00000.png
# 1     42      45       5       5      36      40        1  Test/00001.png
# 2     48      52       6       6      43      47       38  Test/00002.png
# 3     27      29       5       5      22      24       33  Test/00003.png
# 4     60      57       5       5      55      52       11  Test/00004.png

# %%
# definir une taille fixe des rois 


for index,row in df_test.iterrows():

    x1, y1, x2, y2 = int(row["Roi.X1"]), int(row["Roi.Y1"]), int(row["Roi.X2"]), int(row["Roi.Y2"])

    df_test.at[index,"Roi_height"] = y2-y1+1
    df_test.at[index,"Roi_width"] = x2-x1+1

    #print(df_test.at[index,"Roi_height"])
    #print(df_test.at[index,"Roi_width"])

# %%
print(df_test["Roi_height"].max())
print(df_test["Roi_width"].max())

print(df_test["Roi_height"].min())
print(df_test["Roi_width"].min())

print(df_test.describe())
# Out:
# 194.0
# 223.0
# 16.0
# 16.0
#               Width        Height        Roi.X1        Roi.Y1        Roi.X2  \
# count  12630.000000  12630.000000  12630.000000  12630.000000  12630.000000
# mean      50.507759     50.364450      5.998021      5.982423     44.864450
# std       25.088483     23.698908      1.543954      1.427424     23.776102
# min       25.000000     25.000000      1.000000      5.000000     20.000000
# 25%       34.000000     35.000000      5.000000      5.000000     29.000000
# 50%       43.000000     43.000000      6.000000      6.000000     38.000000
# 75%       58.000000     57.000000      6.000000      6.000000     53.000000
# max      266.000000    232.000000     23.000000     19.000000    244.000000
#
#              Roi.Y2       ClassId    Roi_height     Roi_width
# count  12630.000000  12630.000000  12630.000000  12630.000000
# mean      44.758116     15.551069     39.775693     39.866429
# std       22.494697     11.947123     21.306561     22.466737
# min       20.000000      0.000000     16.000000     16.000000
# 25%       29.000000      5.000000     25.000000     24.000000
# 50%       38.000000     12.000000     33.000000     33.000000
# 75%       52.000000     25.000000     48.000000     48.000000
# max      212.000000     42.000000    194.000000    223.000000

# %%
## parcourir toutes les images et recuperer uniquement les pixels dans le roi
# definir la taille fixe a 64,64 


for index, row in df_test.iterrows():
    
    img_path = "archive/" + row["Path"]
    img = cv2.imread(img_path)
    

    
    x1, y1, x2, y2 = int(row["Roi.X1"]), int(row["Roi.Y1"]), int(row["Roi.X2"]), int(row["Roi.Y2"])

    img_roi = img[y1:y2, x1:x2]

    h=img_roi.shape[0]
    w=img_roi.shape[1]

    cote = max(h,w)

    carre_noir = np.zeros(shape=(cote,cote,3),dtype=np.uint8)

    x_offset = (cote-w) // 2
    y_offset = (cote-h) // 2

    carre_noir[y_offset:y_offset+h,x_offset:x_offset+w] = img_roi

    img_finale =  cv2.resize(carre_noir,(64,64),interpolation=cv2.INTER_AREA)

    path_save = "archive/test_Roi/" + row["Path"].replace("test/", "")
    
    os.makedirs(os.path.dirname(path_save), exist_ok=True)

    cv2.imwrite(path_save, img_finale)
